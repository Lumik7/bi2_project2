# %% [markdown]
# # Initial EDA
#
# In this notebook we explore the preprocessed data tables

# %%
# Load the "autoreload" extension
# %load_ext autoreload
# %autoreload 2

import sys
import os
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
#%matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')

# add the 'src' directory as one where we can import modules
src_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, 'src'))
sys.path.append(src_dir)

# self written packages
from data import data_utils

# %% [markdown]
# ## Read files from directory of processed data tables

# %%
dfs = data_utils.read_csv_from_dir(dir_name="processed")
print("We have {} tables".format(len(dfs)))
# Out:
# We have 11 tables

# %% [markdown]
# ## Head all 11 tables:

# %%
dfs[0].head()
# Out:
#    index T:concept:name  E:amount E:concept:name E:lifecycle:transition  \
# 0      5           A100      71.5    Add penalty               complete
# 1     10         A10000      74.0    Add penalty               complete
# 2     16         A10001      74.0    Add penalty               complete
# 3     21         A10004      74.0    Add penalty               complete
# 4     30         A10008      74.0    Add penalty               complete
#
#    E:time:timestamp
# 0  3/16/07 12:00 AM
# 1  10/1/07 12:00 AM
# 2  9/23/07 12:00 AM
# 3  9/22/07 12:00 AM
# 4  10/1/07 12:00 AM

# %%
dfs[1].head()
# Out:
#    index T:concept:name   E:concept:name E:dismissal E:lifecycle:transition  \
# 0   5342         A12414  Appeal to Judge           G               complete
# 1  10049         A14727  Appeal to Judge         NIL               complete
# 2  10916          A1516  Appeal to Judge         NIL               complete
# 3  11325         A15307  Appeal to Judge         NIL               complete
# 4  12393          A1582  Appeal to Judge           G               complete
#
#    E:time:timestamp
# 0  1/21/08 12:00 AM
# 1  10/9/07 12:00 AM
# 2   1/5/07 12:00 AM
# 3   2/5/08 12:00 AM
# 4  4/24/07 12:00 AM

# %%
dfs[2].head()
# Out:
#    index T:concept:name  E:amount  E:article E:concept:name E:dismissal  \
# 0      0             A1      35.0      157.0    Create Fine         NIL
# 1      2           A100      35.0      157.0    Create Fine         NIL
# 2      7         A10000      36.0      157.0    Create Fine         NIL
# 3     12         A10001      36.0      157.0    Create Fine         NIL
# 4     18         A10004      36.0      157.0    Create Fine         NIL
#
#   E:lifecycle:transition  E:org:resource  E:points  E:time:timestamp  \
# 0               complete           561.0       0.0  7/24/06 12:00 AM
# 1               complete           561.0       0.0   8/2/06 12:00 AM
# 2               complete           561.0       0.0   3/9/07 12:00 AM
# 3               complete           537.0       0.0  3/19/07 12:00 AM
# 4               complete           537.0       0.0  3/20/07 12:00 AM
#
#   E:vehicleClass
# 0              A
# 1              A
# 2              A
# 3              A
# 4              A

# %%
dfs[3].head()
# Out:
#    index T:concept:name                    E:concept:name  \
# 0     15         A10001  Insert Date Appeal to Prefecture
# 1    262         A10102  Insert Date Appeal to Prefecture
# 2    274         A10107  Insert Date Appeal to Prefecture
# 3    317         A10125  Insert Date Appeal to Prefecture
# 4    572         A10236  Insert Date Appeal to Prefecture
#
#   E:lifecycle:transition  E:time:timestamp
# 0               complete   8/2/07 12:00 AM
# 1               complete  9/10/07 12:00 AM
# 2               complete  7/27/07 12:00 AM
# 3               complete   8/1/07 12:00 AM
# 4               complete   8/9/07 12:00 AM

# %%
dfs[4].head()
# Out:
#    index T:concept:name            E:concept:name E:lastSent  \
# 0      4           A100  Insert Fine Notification          P
# 1      9         A10000  Insert Fine Notification          P
# 2     14         A10001  Insert Fine Notification          P
# 3     20         A10004  Insert Fine Notification          P
# 4     29         A10008  Insert Fine Notification          P
#
#   E:lifecycle:transition E:notificationType  E:time:timestamp
# 0               complete                  P  1/15/07 12:00 AM
# 1               complete                  P   8/2/07 12:00 AM
# 2               complete                  P  7/25/07 12:00 AM
# 3               complete                  P  7/24/07 12:00 AM
# 4               complete                  P   8/2/07 12:00 AM

# %%
dfs[5].head()
# Out:
#    index T:concept:name                    E:concept:name  \
# 0    603         A10249  Notify Result Appeal to Offender
# 1    784         A10338  Notify Result Appeal to Offender
# 2   1430         A10619  Notify Result Appeal to Offender
# 3   1946         A10858  Notify Result Appeal to Offender
# 4   4529         A12027  Notify Result Appeal to Offender
#
#   E:lifecycle:transition   E:time:timestamp
# 0               complete   1/25/08 12:00 AM
# 1               complete  10/31/07 12:00 AM
# 2               complete  11/16/07 12:00 AM
# 3               complete   6/24/08 12:00 AM
# 4               complete   1/25/08 12:00 AM

# %%
dfs[6].head()
# Out:
#    index T:concept:name E:concept:name E:lifecycle:transition  \
# 0     11         A10000        Payment               complete
# 1     24         A10005        Payment               complete
# 2     26         A10007        Payment               complete
# 3     36         A10009        Payment               complete
# 4     37         A10009        Payment               complete
#
#    E:paymentAmount   E:time:timestamp  E:totalPaymentAmount
# 0             87.0    9/9/08 12:00 AM                  87.0
# 1             36.0   3/21/07 12:00 AM                  36.0
# 2             36.0   3/23/07 12:00 AM                  36.0
# 3             35.0   10/1/07 12:00 AM                  35.0
# 4             22.0  10/31/07 12:00 AM                  57.0

# %%
dfs[7].head()
# Out:
#    index T:concept:name                         E:concept:name  \
# 0    602         A10249  Receive Result Appeal from Prefecture
# 1    783         A10338  Receive Result Appeal from Prefecture
# 2   1429         A10619  Receive Result Appeal from Prefecture
# 3   1945         A10858  Receive Result Appeal from Prefecture
# 4   4528         A12027  Receive Result Appeal from Prefecture
#
#   E:lifecycle:transition   E:time:timestamp
# 0               complete   1/22/08 12:00 AM
# 1               complete  10/23/07 12:00 AM
# 2               complete  11/12/07 12:00 AM
# 3               complete   5/28/08 12:00 AM
# 4               complete   1/21/08 12:00 AM

# %%
dfs[8].head()
# Out:
#    index T:concept:name             E:concept:name E:dismissal  \
# 0     17         A10001  Send Appeal to Prefecture           #
# 1    263         A10102  Send Appeal to Prefecture           #
# 2    276         A10107  Send Appeal to Prefecture           #
# 3    320         A10125  Send Appeal to Prefecture         NIL
# 4    574         A10236  Send Appeal to Prefecture           #
#
#   E:lifecycle:transition   E:time:timestamp
# 0               complete   9/24/07 12:00 AM
# 1               complete  10/25/07 12:00 AM
# 2               complete   9/24/07 12:00 AM
# 3               complete   9/24/07 12:00 AM
# 4               complete   10/2/07 12:00 AM

# %%
dfs[9].head()
# Out:
#    index T:concept:name E:concept:name  E:expense E:lifecycle:transition  \
# 0      1             A1      Send Fine       11.0               complete
# 1      3           A100      Send Fine       11.0               complete
# 2      8         A10000      Send Fine       13.0               complete
# 3     13         A10001      Send Fine       13.0               complete
# 4     19         A10004      Send Fine       13.0               complete
#
#     E:time:timestamp
# 0   12/5/06 12:00 AM
# 1  12/12/06 12:00 AM
# 2   7/17/07 12:00 AM
# 3   7/17/07 12:00 AM
# 4   7/17/07 12:00 AM

# %%
dfs[10].head()
# Out:
#    index T:concept:name              E:concept:name E:lifecycle:transition  \
# 0      6           A100  Send for Credit Collection               complete
# 1     22         A10004  Send for Credit Collection               complete
# 2     31         A10008  Send for Credit Collection               complete
# 3     42          A1001  Send for Credit Collection               complete
# 4     47         A10010  Send for Credit Collection               complete
#
#    E:time:timestamp
# 0  3/30/09 12:00 AM
# 1  3/30/09 12:00 AM
# 2  3/30/09 12:00 AM
# 3  3/30/09 12:00 AM
# 4  3/30/09 12:00 AM
